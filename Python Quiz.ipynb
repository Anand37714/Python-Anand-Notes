# %%
#1what value is stored in result?
a=5 + 3 * 2 ** 2 
print(a)

#2What does the assignment operator x //= 3 perform?
#Divides x by 3 and keeps the remainder.
#Divides x by 3 and returns a float.
#Performs floor division on x by 3 and updates x.
#Raises x to the power of 3.
x=14 #14 is the dividend and #3 is the divisor
Result=x//3 #It's a floor division 
print(Result) #gives the quotient only which is 4 (Remainder is 2)
print(type(Result))

#3If you use the f-string format f"{name:>10}", what happens to the output?
#The text is converted to uppercase.
#The text is truncated to 10 characters.
#The text is right-aligned within a field of 10 characters.
#The text is repeated 10 times.
name="box"
print(name)
print(f"|{name:>010}|")

#4Which function would you use to verify if two different variables are pointing to the exact same location in memory?
#type()
#loc()
#id()
#address()


#5Which of the following correctly captures a user's age as an integer from a terminal input?
#age = input(int("Enter age: "))
#age = int(input("Enter age: "))
#age = input("Enter age: ").to_int()
#age = cast(int, input())
age = int(input("Enter the age: "))
print ("The age of the Person is:",age)

#6What will be the data type of the result for the expression x = 10 / 2?
#int
#float
#bool
#decimal
x=15
Result=x/2 #It's a True Division, Gives the result in float data type
print(Result)
print(type(Result))
      

#7Which bitwise operator is used to flip all the bits of a binary number? Pending
#& (AND)
#| (OR)
#^ (XOR)
#~ (NOT)
b=25
print(b)
print(~b)


#8 A developer wants to ensure that a floating-point number pi = 3.14159 is printed as 3.14. Which f-string format is correct?
#f"{pi:2}"
#f"{pi:.2f}"
#f"{pi:round.2}"
#f"{pi:precision=2}"
import math
print(math.pi)
print(f"{math.pi:.2f}") #Pending : Need Explanation of f

#9What is the result of the logical expression True or False and False?
#True
#False
#None
#Error
#Ans True
result = True or False and False # True or False --> True
print(result)
print(False and False) #F
print(False or False) # F
print(True and False) #F
print(True or False) #T
print(True and True) #T
print(True or True) #T

#10 In Python, what is the value of a variable that has been declared but not yet assigned any "real" data?
#0
#"" (Empty string)
# #None
#False
#Ans None
a=None
print(a)
print(type(a))

student_name = None
print(student_name)
print(type(student_name))

student_name = "Anand"
print(student_name)
print(type(student_name))
# Out:
# 17
# 4
# <class 'int'>
# box
# |0000000box|
# The age of the Person is: 40
# 7.5
# <class 'float'>
# 25
# -26
# 3.141592653589793
# 3.14
# True
# False
# False
# False
# True
# True
# True
# None
# <class 'NoneType'>
# None
# <class 'NoneType'>
# Anand
# <class 'str'>
