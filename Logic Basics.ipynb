# %% [markdown]
# #Precedence and Associativity
#
# An **expression** is anything that evaluates to a value — `2 + 3`, `x * y`, `True and x > 5`.
#
# ### Precedence Table (High → Low)
#
# | Priority | Operator(s) | Description |
# |----------|-------------|-------------|
# | 1 | `()` | Parentheses |
# | 2 | `**` | Exponentiation |
# | 3 | `+x` `-x` | Unary sign |
# | 4 | `*` `/` `//` `%` | Multiply / Divide |
# | 5 | `+` `-` | Add / Subtract |
# | 6 | `<<` `>>` | Bitwise shift |
# | 7 | `&` `^` `\|` | Bitwise AND/XOR/OR |
# | 8 | `==` `!=` `>` `<` `>=` `<=` | Comparison |
# | 9 | `not` | Logical NOT |
# | 10 | `and` | Logical AND |
# | 11 | `or` | Logical OR |
#
# **Associativity:** most operators → left to right ·
#
# `**` → right to left (only exception)

# %%
#Precedence decides which operator runs first
#In an expression when there are multiple operators

#Predict the output
print(3+4*2) #11
print(10/2+3) #8
print(10/(2+3)) #2
print(2**2**3) #2**8=256 (for ** --> right to left so first it will do 2**3=8 then 2**8)
print(16**2)
print(16*16)
print(15%4+2*3) #9 (% means gives the remainder-->15%4 gives the remainder as 3)
print(not 10>5 or 3<7) #not true or true --> false or true -- > true
# Out:
# 11
# 8.0
# 2.0
# 256
# 256
# 256
# 9
# True

# %%
#Predict the output
x=5
print(x>3 and x<10 or x==7) #true and true or false --> true or false --> true
print(x>3 and (x<10 or x==7)) #true and (true or flase) --> true and true --> true
# Out:
# True
# True

# %%
#Predict the output
x=12
print(x>3 and x<10 or x==7) #true and false or false --> false or false --> false
print(x>3 and (x<10 or x==7)) #true and (false or flase) --> true and false --> false
# Out:
# False
# False

# %%
#Chained comparision
# Predict the output

marks = 73
print(90<=marks<=100) #--> 90<= marks and marks<=100 --> False and True --> False
print(70<=marks<=89) #--> 70<= marks and marks<=89 --> True and True --> True
print(50<=marks<=69) #--> 50<= marks and marks<=69 --> True and False --> False
# Out:
# False
# True
# False

# %%
#print with sep and end

#sep-->seperator

print("phone","mouse","laptop",sep="*")
print("phone","mouse","laptop",sep="/")
print("phone","mouse","laptop",sep="*")
print("phone","mouse","laptop",sep="\n")

#end-->change the hpw the print statement ends
print("phone","mouse","laptop")
print("phone","mouse","laptop",end="*")
print("phone","mouse","laptop",end="/")
print("abc")
# Out:
# phone*mouse*laptop
# phone/mouse/laptop
# phone*mouse*laptop
# phone
# mouse
# laptop
# phone mouse laptop
# phone mouse laptop*phone mouse laptop/abc

# %%
#print a list in one line

products=["phone","mouse","laptop"]
for i in products:
    print(i,end=" ")
# Out:
# phone mouse laptop

# %% [markdown]
# | Specifier | What it formats | Example |
# |---|---|---|
# | `%d` | Integer | `"%d" % 42` → `"42"` |
# | `%f` | Float | `"%f" % 3.14` → `"3.140000"` |
# | `%.2f` | Float with 2 decimal places | `"%.2f" % 3.14159` → `"3.14"` |
# | `%s` | String | `"%s" % "Laptop"` → `"Laptop"` |
# | `%e` | Scientific notation | `"%e" % 85000` → `"8.500000e+04"` |
# | `%g` | Shorter of %f or %e | `"%g" % 85000` → `"85000"` |

# %%
price=8500.7866
print("price: %d" %price)

price=8500.7866
print("price: %f" %price)

print("price: %.2f" %price)

print("price: %s" %price)

print("price: %e" %price)

print("price: %g" %price)
# Out:
# price: 8500
# price: 8500.786600
# price: 8500.79
# price: 8500.7866
# price: 8.500787e+03
# price: 8500.79

# %%
values=[0.000001,42.5,85000000000]

for v in values:
    print("%g" %v)
# Out:
# 1e-06
# 42.5
# 8.5e+10

# %%
#nonlocal-->lets an inner function modify a variable from its enclosing(outer) function

def outer():
    count=0 #nonlocal or enclosed variable
    def inner():
        nonlocal count
        count+=1
        print(count)
    return inner()
outer()
# Out:
# 1
