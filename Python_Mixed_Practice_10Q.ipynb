# %% [markdown]
# # Python Mixed Practice — 10 Questions
# ### Covers: Data Types, Operators, Data Structures, Control Flow, Loops, Functions
# ### E-Commerce Context
# ---

# %% [markdown]
# ## Question 1 — Data Types and Operators
#
# You are building a billing system for QuickCart.

# %%
product_name  = "Laptop"
price         = 85000
discount_pct  = 10.5
in_stock      = True
offer_code    = None

# 1a. Print the data type of each variable using type()
print(type(product_name))
print(type(price))
print(type(discount_pct))
print(type(in_stock))
print(type(offer_code))

# 1b. Print the memory address of price using id()
print(id(product_name))
print(id(price))
print(id(discount_pct))
print(id(in_stock))
print(id(offer_code))

# 1c. Calculate the final price after discount and store in final_price
final_price = price-price*10.5/100
print(final_price)

# 1d. Check if in_stock is True AND final_price > 50000
#     Print True or False
print(in_stock and final_price > 50000)

# 1e. Check if offer_code is None
#     Print: "No offer applied" if None else "Offer applied"
if offer_code is None:
    print("No offer applied")
else:
    print("Offer applied")
# 1f. Print final_price with 2 decimal places and comma separator
#     using f-string
#     Expected: Final Price: Rs.76,075.00
print(f"Final_price is RS-{final_price:,.2f}")
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'bool'>
# <class 'NoneType'>
# 2773056829360
# 2773056657808
# 2773055190864
# 140716722621184
# 140716722621248
# 76075.0
# True
# No offer applied
# Final_price is RS-76,075.00

# %% [markdown]
# ---
# ## Question 2 — Lists
#
# Manage a product inventory.

# %%
products = ["Mobile", "Laptop", "Tablet", "Earbuds", "Smartwatch", "Camera"]
prices   = [25000, 85000, 45000, 5000, 15000, 32000]

# 2a. Print the first and last product using indexing
print(f"First Product - {products[0]}-{prices[0]}")
print(f"Lat Product - {products[-1]}-{prices[-1]}")
# 2b. Print the first 3 products using slicing

# 2c. Print every alternate product starting from index 0

# 2d. Add "Headphones" to the end of products and 8000 to prices

# 2e. Remove "Earbuds" from products and its price from prices
#     Hint — find the index first

# 2f. Sort prices in descending order and print

# 2g. Print total, highest and lowest price
# Out:
# First Product - Mobile-25000
# Lat Product - Camera-32000

# %% [markdown]
# ---
# ## Question 3 — Tuples, Sets and Dictionaries
#
# Work with order and customer data.

# %%
# TUPLES
order = ("ORD001", "Rahul Verma", "Laptop", 2, 85000, "2024-03-15")
#         id        customer       product   qty  price   date

# 3a. Unpack all six values into separate variables

# 3b. Print: "Rahul Verma ordered 2 Laptop(s) on 2024-03-15 worth Rs.85000"
#     using unpacked variables

# 3c. Try changing the price to 90000 — what happens?

# SETS
week1_customers = {"C001", "C002", "C003", "C004", "C005"}
week2_customers = {"C003", "C004", "C005", "C006", "C007"}

# 3d. Customers who ordered both weeks
# 3e. All unique customers across both weeks
# 3f. Customers who ordered week 1 but not week 2 (churned)
# 3g. New customers in week 2

# DICTIONARIES
customer = {
    "id"      : "C001",
    "name"    : "Rahul Verma",
    "city"    : "Bengaluru",
    "orders"  : 5,
    "total"   : 125000
}

# 3h. Print name and city using direct access
# 3i. Access "membership" using .get() with default "Not a member"
# 3j. Add key "tier" with value "Gold" if total >= 100000 else "Silver"
# 3k. Print all key-value pairs using .items()

# %% [markdown]
# ---
# ## Question 4 — String Methods
#
# Clean and format customer and product data.

# %%
raw_name    = "  rahul verma  "
product_csv = "Laptop,Electronics,85000,10"
order_note  = "Order ORD001 placed. ORD001 is confirmed. ORD001 will ship today."
customer_id = "C00742"

# 4a. Clean raw_name — strip spaces and title case

# 4b. Split product_csv by comma into a list
#     Unpack into: name, category, price, stock
#     Convert price and stock to correct types

# 4c. Count how many times "ORD001" appears in order_note

# 4d. Replace "ORD001" with "ORD999" in order_note

# 4e. Check if customer_id starts with "C"

# 4f. Join ["QuickCart", "Bengaluru", "India"] with " | " separator

# 4g. Pad customer number "42" with zeros to make it 6 characters

# %% [markdown]
# ---
# ## Question 5 — Control Flow
#
# Build an order processing system with conditions.

# %%
order_amount   = 3500
payment_status = "paid"
is_member      = True
stock          = 5
order_status   = "dispatched"

# 5a. if-elif-else
#     Print "Platinum" if order_amount >= 5000
#     Print "Gold"     if order_amount >= 2000
#     Print "Silver"   if order_amount >= 1000
#     Print "Basic"    for anything below

# 5b. Nested if
#     If payment is paid and stock > 0 — print "Order confirmed and dispatched"
#     If payment is paid but stock 0  — print "Payment done but out of stock"
#     If payment not paid             — print "Complete payment first"

# 5c. Logical operators
#     Print "Free delivery" if payment is paid AND (order_amount >= 1000 OR is_member)
#     Otherwise print "Delivery charge applicable"

# 5d. Ternary
#     Assign "Member discount: 15%" if is_member else "No discount"
#     Print the result

# 5e. match-case on order_status
#     processing       → "Order is being packed"
#     dispatched       → "Order is on its way"
#     delivered        → "Order delivered"
#     cancelled        → "Order cancelled"
#     anything else    → "Status unknown"

# %% [markdown]
# ---
# ## Question 6 — For Loops
#
# Process a list of orders using loops.

# %%
orders = [
    {"id": "ORD001", "status": "delivered", "amount": 1500, "items": ["shoes", "bag"]},
    {"id": "ORD002", "status": "pending",   "amount": 800,  "items": ["laptop"]},
    {"id": "ORD003", "status": "delivered", "amount": 2300, "items": ["shirt", "jeans", "belt"]},
    {"id": "ORD004", "status": "cancelled", "amount": 450,  "items": ["earbuds"]},
    {"id": "ORD005", "status": "delivered", "amount": 1100, "items": ["mobile", "case"]}
]

# 6a. Print id and amount of all orders

# 6b. Print id and amount of delivered orders only

# 6c. Print each order id followed by its items (nested loop)
#     Expected:
#     ORD001:
#       - shoes
#       - bag
#     ORD002:
#       - laptop ...

# 6d. Calculate total amount of delivered orders
#     Print: Total delivered: Rs.4900

# 6e. Use enumerate to print orders with a number starting from 1
#     Expected:
#     1. ORD001 — delivered — Rs.1500
#     2. ORD002 — pending   — Rs.800 ...

# %% [markdown]
# ---
# ## Question 7 — While Loop and Control Keywords
#
# Simulate a cart and checkout flow.

# %%
# 7a. While loop
#     stock = 8
#     Keep printing "Item sold — stock: X" and reduce stock by 1
#     Stop when stock reaches 0

stock = 8


# 7b. break
#     Loop through products
#     Stop and print "Found it" when you reach "Tablet"
#     Print "Checking: X" for everything before it

products = ["Mobile", "Laptop", "Tablet", "Smartwatch", "Earbuds"]


# 7c. continue
#     Loop through order_amounts
#     Skip zeros
#     Print "Processing: Rs.X" for valid amounts

order_amounts = [1500, 0, 800, 0, 2300, 0, 1100]


# 7d. Mixed — break and continue together
#     Loop through orders below
#     Skip orders with amount 0 using continue
#     Stop at cancelled using break
#     Print only delivered: "ORD001 — delivered — Rs.1500"

orders = [
    {"id": "ORD001", "status": "delivered", "amount": 1500},
    {"id": "ORD002", "status": "pending",   "amount": 0},
    {"id": "ORD003", "status": "cancelled", "amount": 800},
    {"id": "ORD004", "status": "delivered", "amount": 2300},
    {"id": "ORD005", "status": "delivered", "amount": 0}
]

# %% [markdown]
# ---
# ## Question 8 — Comprehensions
#
# Use list and dict comprehensions on order data.

# %%
order_amounts = [1500, 800, 2300, 450, 1100, 3200]

orders = [
    {"id": "ORD001", "status": "delivered", "amount": 1500},
    {"id": "ORD002", "status": "pending",   "amount": 800},
    {"id": "ORD003", "status": "delivered", "amount": 2300},
    {"id": "ORD004", "status": "cancelled", "amount": 450}
]

product_prices = {"Mobile": 25000, "Laptop": 85000, "Tablet": 45000, "Earbuds": 5000}

# 8a. List comprehension — apply 10% discount to all order_amounts

# 8b. List comprehension — filter only amounts above 1000

# 8c. List comprehension — label each amount
#     "Large" if above 1000 else "Small"

# 8d. List comprehension — get IDs of delivered orders only

# 8e. Dict comprehension — apply 10% discount to all product prices

# 8f. Dict comprehension — keep only products above Rs.20000

# 8g. Dict comprehension — create id → amount dict for delivered orders only

# %% [markdown]
# ---
# ## Question 9 — Functions
#
# Write reusable functions for the QuickCart system.

# %%
# 9a. Write a function called get_delivery_charge
#     Takes order_amount
#     Returns "Free"  if amount >= 1000
#     Returns "Rs.49" if amount >= 500
#     Returns "Rs.99" for anything below
#     Test with 1500, 700, 300


# 9b. Write a function called apply_discount
#     Takes amount and percent (default 10)
#     Returns discounted amount
#     Write a Google style docstring for it
#     Test with 85000, then 85000 with 20%


# 9c. Write a function called order_summary
#     Takes a list of order amounts
#     Returns total, average, highest, lowest
#     Unpack and print all four
#     Use: [1500, 800, 2300, 450, 1100]


# 9d. Write a function called process_cart
#     Takes customer_name as regular argument
#     Takes any number of item prices as *args
#     Takes any number of order details as **kwargs
#     Prints:
#       Customer: Rahul
#       Items total: Rs.X
#       Details: key: value for each kwarg
#     Call it with: "Rahul", 1500, 800, 2300,
#                   status="confirmed", city="Bengaluru"

# %% [markdown]
# ---
# ## Question 10 — Mixed Stretch
#
# Build a complete mini order processing pipeline using everything covered.

# %%
from functools import reduce

orders = [
    {"id": "ORD001", "customer": "Rahul",  "status": "delivered", "amount": 1500, "items": ["shoes", "bag"]},
    {"id": "ORD002", "customer": "Priya",  "status": "pending",   "amount": 0,    "items": ["laptop"]},
    {"id": "ORD003", "customer": "Arjun",  "status": "delivered", "amount": 2300, "items": ["shirt", "jeans"]},
    {"id": "ORD004", "customer": "Sneha",  "status": "cancelled", "amount": 800,  "items": ["earbuds"]},
    {"id": "ORD005", "customer": "Vikram", "status": "delivered", "amount": 1100, "items": ["mobile", "case", "charger"]}
]

# Step 1 — Filter delivered orders using filter() and lambda

# Step 2 — Extract amounts from delivered orders using map() and lambda

# Step 3 — Apply 10% discount to all extracted amounts using map()

# Step 4 — Find total of discounted amounts using reduce()

# Step 5 — Write a function called generate_invoice
#           Takes customer name, list of items, final amount
#           Takes tax_percent as default argument (default 18)
#           Calculates tax and total with tax
#           Prints a clean invoice:
#           ----------------------------
#           Customer : Rahul
#           Items    : shoes, bag
#           Amount   : Rs.1,350.00
#           Tax (18%): Rs.243.00
#           Total    : Rs.1,593.00
#           ----------------------------
#           Write a Google style docstring for it

# Step 6 — Call generate_invoice for each delivered order
#           using the discounted amounts from Step 3
