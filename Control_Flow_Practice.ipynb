# %% [markdown]
# # Control Flow — Practice Questions
# ### E-Commerce Context

# %% [markdown]
# ---
# ## Section 1 — if Statement

# %%
order_amount = 2000

# 1. Print "Eligible for cashback" if order_amount is above 1500

# %%
stock = 0

# 2. Print "Item is out of stock" if stock is 0

# %%
payment_status = "paid"

# 3. Print "Order confirmed" if payment_status is "paid"

# %%
discount = 20

# 4. Print "High discount applied" if discount is greater than or equal to 15

# %%
delivery_type = "express delivery"

# 5. Print "Fast shipping selected" if "express" is in delivery_type

# %% [markdown]
# ---
# ## Section 2 — if-else Statement

# %%
stock = 0

# 1. Print "Add to cart" if stock > 0
#    Otherwise print "Notify me when available"

# %%
order_amount = 800

# 2. Print "Free delivery applied" if order_amount >= 1000
#    Otherwise print "Delivery charge: Rs.50"

# %%
payment_status = "pending"

# 3. Print "Order confirmed. Proceed to dispatch" if payment is paid
#    Otherwise print "Payment pending. Order on hold"

# %%
is_member = False

# 4. Print "Welcome back member" if is_member is True
#    Otherwise print "Join now to get benefits"

# %%
order_status = "cancelled"

# 5. Print "Order is active" if order_status is not "cancelled"
#    Otherwise print "Order has been cancelled"

# %% [markdown]
# ---
# ## Section 3 — if-elif-else Statement

# %%
rating = 3.5

# 1. Print "Excellent" if rating >= 4.5
#    Print "Good" if rating >= 3.5
#    Print "Average" if rating >= 2.5
#    Print "Poor" for anything below

# %%
order_amount = 2500

# 2. Print "Platinum — 20% discount" if order_amount >= 5000
#    Print "Gold — 10% discount" if order_amount >= 2000
#    Print "Silver — 5% discount" if order_amount >= 1000
#    Print "No discount" for anything below

# %%
delivery_status = "out for delivery"

# 3. Print appropriate message for each status:
#    "delivered"        → "Order delivered successfully"
#    "out for delivery" → "Your order is on the way"
#    "dispatched"       → "Order dispatched from warehouse"
#    "processing"       → "Order is being processed"
#    anything else      → "Order status unknown"

# %%
quantity = 3

# 4. Print "Bulk order — special pricing" if quantity >= 10
#    Print "Standard order" if quantity >= 5
#    Print "Small order" if quantity >= 1
#    Print "Invalid quantity" for 0 or below

# %%
return_days = 12

# 5. Print "Return accepted — full refund" if return_days <= 7
#    Print "Return accepted — partial refund" if return_days <= 15
#    Print "Return window closed" for anything above

# %% [markdown]
# ---
# ## Section 4 — Nested if

# %%
is_member    = True
order_amount = 800

# 1. If member and order >= 1000 — print "Free delivery + 10% off"
#    If member but order < 1000 — print "Free delivery only"
#    If not member — print "Sign up for benefits"

# %%
payment_status = "paid"
stock          = 0

# 2. If payment is paid and stock > 0 — print "Order confirmed and dispatched"
#    If payment is paid but stock is 0 — print "Payment received but item out of stock"
#    If payment is not paid — print "Complete payment to proceed"

# %%
is_verified  = True
coupon_code  = "SAVE10"

# 3. If user is verified and coupon_code is not empty — print "Coupon applied"
#    If user is verified but no coupon — print "No coupon entered"
#    If user is not verified — print "Verify your account first"

# %%
is_express   = True
order_amount = 1500

# 4. If express is selected and order >= 1000 — print "Express delivery — free"
#    If express is selected but order < 1000 — print "Express delivery — Rs.99"
#    If express not selected — print "Standard delivery — Rs.49"

# %% [markdown]
# ---
# ## Section 5 — Logical Operators

# %%
payment_status = "paid"
stock          = 5

# 1. Print "Order dispatched" only if payment is paid AND stock > 0

# %%
category = "mobile"

# 2. Print "1 year warranty included" if category is "electronics" OR "mobile"

# %%
payment_status = "pending"

# 3. Print "Payment not completed" if payment_status is NOT "paid"

# %%
payment_status = "paid"
order_amount   = 1500
is_member      = True

# 4. Print "Free delivery applied" if payment is paid
#    AND (order_amount >= 1000 OR is_member is True)
#    Otherwise print "Delivery charge applicable"

# %%
payment_status = "paid"
stock          = 5
is_express     = True

# 5. Print "Express delivery confirmed" only if ALL three are True:
#    payment is paid, stock > 0, is_express is True

# %% [markdown]
# ---
# ## Section 6 — Truthy and Falsy

# %%
cart = []

# 1. Check if cart has items using truthy check (not len())
#    Print "Cart has items" or "Cart is empty"

# %%
coupon_code = ""

# 2. Check if coupon_code is provided using truthy check
#    Print "Coupon applied" or "No coupon entered"

# %%
order_amount = 0

# 3. Check if order_amount is non-zero using truthy check
#    Print "Order placed" or "Order amount is zero"

# %%
address = None

# 4. Check if address is provided using truthy check
#    Print "Delivering to address" or "No address found"

# %%
wishlist = ["shoes", "bag", "watch"]

# 5. Check if wishlist has items using truthy check
#    Print "You have items in your wishlist" or "Wishlist is empty"

# %%
discount = 0
free_gift = None
coupon    = ""

# 6. Check each one using truthy and print what is available and what is not
#    discount   → "Discount available" or "No discount"
#    free_gift  → "Free gift included" or "No free gift"
#    coupon     → "Coupon applied" or "No coupon"

# %% [markdown]
# ---
# ## Section 7 — Ternary Operator

# %%
order_amount = 500

# 1. Assign "Free" if order_amount >= 1000 else "Rs.49"
#    Print: "Delivery charge: Free" or "Delivery charge: Rs.49"

# %%
stock = 0

# 2. Assign "Available" if stock > 0 else "Out of Stock"
#    Print the result

# %%
is_member = True

# 3. Assign 15 if is_member else 0
#    Print: "Discount: 15%" or "Discount: 0%"

# %%
payment_status = "paid"

# 4. Assign "Confirmed" if payment_status == "paid" else "Pending"
#    Print: "Order status: Confirmed" or "Order status: Pending"

# %%
rating = 4.2

# 5. Assign "Top rated" if rating >= 4.0 else "Needs improvement"
#    Print the result directly inside print() without using a variable

# %% [markdown]
# ---
# ## Section 8 — match-case

# %%
order_status = "returned"

# 1. Write match-case for:
#    "processing"       → "Order is being packed"
#    "dispatched"       → "Order on its way to you"
#    "delivered"        → "Order delivered"
#    "returned"         → "Return initiated"
#    anything else      → "Status not available"

# %%
payment_method = "UPI"

# 2. Write match-case for:
#    "UPI"          → "UPI payment — instant confirmation"
#    "credit card"  → "Credit card — confirmation in 2 hours"
#    "net banking"  → "Net banking — confirmation in 4 hours"
#    "COD"          → "Cash on delivery — pay at doorstep"
#    anything else  → "Payment method not supported"

# %%
category = "electronics"

# 3. Write match-case for:
#    "electronics"  → "1 year warranty"
#    "clothing"     → "15 day return"
#    "grocery"      → "No return policy"
#    "furniture"    → "Free installation"
#    anything else  → "Standard policy applies"

# %%
refund_status = "approved"

# 4. Write match-case for:
#    "approved"     → "Refund will be credited in 5-7 days"
#    "processing"   → "Refund is being processed"
#    "rejected"     → "Refund request rejected. Contact support"
#    "pending"      → "Refund request under review"
#    anything else  → "Unknown refund status"

# %% [markdown]
# ---
# ## Section 9 — Mixed (Stretch)

# %%
# 1. E-commerce checkout logic
order_amount   = 1200
payment_status = "paid"
stock          = 3
is_member      = True
coupon_code    = ""

# Step 1 — Check if cart is valid (order_amount > 0) using truthy
# Step 2 — Check if payment is paid
# Step 3 — If paid and stock > 0 — confirm order
#           If paid but no stock — inform customer
# Step 4 — If member — print "Member discount: 10% off"
#           else — print "No member discount"
# Step 5 — Use ternary to assign delivery charge:
#           Free if order >= 1000, else Rs.49
# Step 6 — Print final summary using f-string

# %%
# 2. Product review system
rating       = 4.7
review_count = 0
verified     = True

# Step 1 — Check if review_count is non-zero using truthy
#           Print "Reviews available" or "No reviews yet"
# Step 2 — Use if-elif-else to classify rating:
#           >= 4.5 → Excellent, >= 3.5 → Good, >= 2.5 → Average, else → Poor
# Step 3 — Use ternary to assign badge:
#           "Verified Purchase" if verified else "Unverified"
# Step 4 — Print: "[badge] | Rating: [rating] | [classification]"

# %%
# 3. Return request system
order_status = "delivered"
return_days  = 5
reason       = "damaged"

# Step 1 — Use match-case on order_status:
#           Only "delivered" can be returned — print "Return eligible"
#           Any other status — print "Return not applicable" and stop
# Step 2 — If eligible, check return_days:
#           <= 7  → full refund
#           <= 15 → partial refund
#           else  → return window closed
# Step 3 — Use match-case on reason:
#           "damaged"    → "Refund + replacement offered"
#           "wrong item" → "Exchange initiated"
#           "not needed" → "Store credit issued"
#           else         → "Standard return process"
